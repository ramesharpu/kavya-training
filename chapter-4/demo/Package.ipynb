# %% [markdown]
# # Package
# Inside the folder, if a blankfile with the name "__init__.py" is added, then that folder becomes a package

# %% [markdown]
# ---
# importing package and working with it

# %%
import shapes

# %%
shapes.geometry.area_of_circle(25)
# Out:
# 1963.4937499999999

# %% [markdown]
# ---
# importing package and module, and working with it

# %%
from shapes import geometry

# %%
geometry.area_of_circle(25)
# Out:
# 1963.4937499999999

# %% [markdown]
# ---
# imporing package, module and function, then working with it

# %%
from shapes.geometry import area_of_circle

# %%
area_of_circle(25)
# Out:
# 1963.4937499999999
