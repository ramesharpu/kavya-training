# %% [markdown]
# # Python Libraries

# %% [markdown]
# Python Libraries are collections of **pre-written code, modules and functions** that allow developers to perform complex tasks without writing the logic from scratch.
#
# The ecosystem consists of two main branches:
# * build-in python standard libraries
# * hundres of thousands of third-party packages ==> available via the python package index (PyPI) ==> https://pypi.org/

# %% [markdown]
# ---
# # Key Build-in Libraries(Standard Library)

# %% [markdown]
# These modules require no installation and are ready right out of the box
# **Example:**
# * **os**: Handles interaction with operating system file directories
# * **sys**: Modifies system-specific parameters and controls runtime script settings
# * **datatime**: Essential module built for parsing, calculating and manipulating dates and times
# * **math**: math library provides a comphrehensive collection of mathematical functions and constants for floating-point arithmetic

# %% [markdown]
# ---
# # OS related example

# %%
import os

# %%
help(os)

# %%
os.cpu_count()

# %%
os.mkdir("xyz")

# %% [markdown]
# ---
# # date and time related example

# %%
import datetime

# %%
help(datetime)

# %%
from datetime import date, datetime, time, timezone

# %%
print(datetime.now())

# %%
print(date.today())

# %%
datetime.now()

# %%
now = datetime.now()
print(now.hour)

# %% [markdown]
# ---
# # Math library

# %%
import math

# %%
math.sin(30)

# %%
math.pow(2, 3)

# %%
help(math)

# %% [markdown]
# ---
# # Statistics module

# %%
import statistics

data = [2, 3, 4, 4, 4, 4, 5, 5, 7, 9]

print(statistics.mean(data))
# Out:
# 4.7

# %%
import statistics as st

data = [2, 3, 4, 4, 4, 4, 5, 5, 7, 9, 8]
print(st.mean(data)) # average
# Out:
# 5

# %%
print(st.median(data)) # getting the middle value
# Out:
# 4

# %%
print(st.mode(data)) # most frequent value
# Out:
# 4

# %%
print(st.stdev(data)) # standard deviation
# Out:
# 2.1447610589527217

# %%
print(st.variance(data)) # variance
# Out:
# 4.6

# %% [markdown]
# ---
# # String Functions

# %%
name = "kavya"
print(name.upper())
# Out:
# KAVYA

# %%
print(name.lower())
# Out:
# kavya

# %%
print(name.capitalize())
# Out:
# Kavya

# %%
print("KaVya".casefold())
# Out:
# kavya

# %%
print(name.isascii())
# Out:
# True

# %%
name.title()
# Out:
# 'Kavya'

# %%
name.split('v')
# Out:
# ['ka', 'ya']

# %%
name.replace("v", "T")
# Out:
# 'kaTya'

# %%
"asdfksdfkdkdsfkkkdksadfk".count('k')
# Out:
# 8

# %%
# Example-1 - Join related examples

first_name = 'John'
last_name = 'Rambo'

output = " ".join([first_name, last_name])
print(output)
# Out:
# John Rambo

# %%
"*".join("kavya")
# Out:
# 'k*a*v*y*a'

# %%
" # # ".join("kavya")
# Out:
# 'k # # a # # v # # y # # a'

# %%
" ".join(['John', 'Rambo'])
# Out:
# 'John Rambo'

# %%
" ".join(['John', 'Rambo', str(123)])
# Out:
# 'John Rambo 123'

# %%
stm = "John's age is -"
age = 25
"#".join([stm, str(age)])
# Out:
# "John's age is -#25"

# %%
stm = "John's age is -"
age = 25
" ".join([stm, str(age)])
# Out:
# "John's age is - 25"

# %%
# Example-2: split the words in a sentence

"I love my dog".split()
# Out:
# ['I', 'love', 'my', 'dog']

# %%
"I love my dog".split(" ")
# Out:
# ['I', 'love', 'my', 'dog']

# %%
"John Rambo, Barrak Obama, Deepak Sharma, Atul Verma".split(",")
# Out:
# ['John Rambo', ' Barrak Obama', ' Deepak Sharma', ' Atul Verma']

# %%
str(250.56).split(".")
# Out:
# ['250', '56']

# %%
# Example-3: character splitting

# using '*'
print(*"kavya")
# Out:
# k a v y a

# %%
# using * and converting to list
print([*"kavya"])
# Out:
# ['k', 'a', 'v', 'y', 'a']

# %%
# using list function
list("kavya")
# Out:
# ['k', 'a', 'v', 'y', 'a']

# %%
# using looping
for char in "kavya":
    print(char)
# Out:
# k
# a
# v
# y
# a

# %% [markdown]
# ---
# # Third party libraries
# Third party libraries are available in Python Package Index (PyPI)
#
# **Example:**
# * **NumPy**: NumPy is the fundamental package for scientific computing in Python
# * **Pandas**: Essential for data manipulation, cleaning and structing tabular data analysis using DataFrames
# * **SciPy**: Advanced library used for scientific, engineering, and mathematical calculations
# * **Scikit-Learn**: Package for classic machine learning algorithms, clustering and regression
# * **PyTorch**: Open-source deep learning framework heavily favored in modern AI research
# * **TensorFlow:** Google's Scalable end-to-end framework for traing and deploying deep neural networks

# %% [markdown]
# ---
# # NumPy Example

# %%
# installing numpy
pip install numpy

# %%
import numpy as np

# %%
np.__version__

# %%
np.arange(15).reshape(3, 5)

# %% [markdown]
# ---
# # Pandas example

# %%
# install pandas
pip install pandas

# %%
import pandas as pd

# %%
pd.DataFrame({'Apples': [1,2,3], 'Banana': [4,5,6]})

# %% [markdown]
# ---
# # Namespace (extra information)
#
# In python, a namespace is a system that maps names to objects to prevent name conficts.
# Internally, Python implements namespaces as a standard dictionaries, where the keys are your variable/function names and the values are objects they reference
#
# There are 4 types of namespaces
# * Built-in namespace
# * Global namespace
# * Enclosing namespace
# * Local namespace

# %%
# Global namespace
x = "kavya"

def add():
    # local namespace
    y = 25

# print(globals())
print(locals())
